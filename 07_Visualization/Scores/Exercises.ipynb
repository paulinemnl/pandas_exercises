# %% [markdown]
# # Scores

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
# ***Exercise based on [Chris Albon](http://chrisalbon.com/) work, the credits belong to him.***
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Step 2. Create the DataFrame that should look like the one below.

# %%
df = pd.DataFrame({
    'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
    'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
    'age': [42, 52, 36, 24, 73],
    'female': [0, 1, 1, 0, 1],
    'preTestScore': [4, 24, 31, 2, 3],
    'postTestScore': [25, 94, 57, 62, 70]
})
df
# Out:
#   first_name last_name  age  female  preTestScore  postTestScore
# 0      Jason    Miller   42       0             4             25
# 1      Molly  Jacobson   52       1            24             94
# 2       Tina       Ali   36       1            31             57
# 3       Jake    Milner   24       0             2             62
# 4        Amy     Cooze   73       1             3             70

# %% [markdown]
# ### Step 3. Create a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age
# #### Hint: Don't forget to place the labels

# %%
sns.scatterplot(data=df, x='preTestScore', y='postTestScore', size='age')
plt.title("preTestScore x postTestScore")
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
# Out:
# Text(0, 0.5, 'postTestScore')

# %% [markdown]
# ### Step 4. Create a Scatterplot of preTestScore and postTestScore.
# ### This time the size should be 4.5 times the postTestScore and the color determined by sex

# %%
g = sns.scatterplot(data=df, x='preTestScore', y='postTestScore',
                    size='postTestScore', sizes=[i*4.5 for i in df.postTestScore], size_order=df.postTestScore,
                    hue='female')
# h, l = g.get_legend_handles_labels()
# plt.legend(h[0:3],l[0:3])
plt.title("preTestScore x postTestScore")
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
# Out:
# Text(0, 0.5, 'postTestScore')

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %% [markdown]
# ### Создать график preTestScore x postTestScore. Размер preTestScore * 10, разбить по полу, убрать легенду размера

# %%
# здесь нет size_order и поэтому размеры не увеличиваются с увеличением preTestScore (по оси x)
g = sns.scatterplot(data=df, x='preTestScore', y='postTestScore', size='preTestScore', sizes=[i*10 for i in df.preTestScore], hue='female')
h, l = g.get_legend_handles_labels()
plt.legend(h[0:3],l[0:3])
plt.title("preTestScore x postTestScore")
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
# Out:
# Text(0, 0.5, 'postTestScore')

# %%
# здесь есть size_order и поэтому размеры увеличиваются с увеличением preTestScore (по оси x)
g = sns.scatterplot(data=df, x='preTestScore', y='postTestScore', size='preTestScore', sizes=[i*10 for i in df.preTestScore], size_order=df.preTestScore, hue='female')
h, l = g.get_legend_handles_labels()
plt.legend(h[0:3],l[0:3])
plt.title("preTestScore x postTestScore")
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
# Out:
# Text(0, 0.5, 'postTestScore')

# %% [markdown]
# ### Создать график preTestScore x postTestScore; поменять размер в зависимости от пола

# %%
# мужчинам размер 10, женщинам - 100
g = sns.scatterplot(data=df, x='preTestScore', y='postTestScore', size=df.female, sizes=[10, 100], size_order=[0, 1])
# h, l = g.get_legend_handles_labels()
# plt.legend(h[0:3],l[0:3])
plt.title("preTestScore x postTestScore")
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
# Out:
# Text(0, 0.5, 'postTestScore')

# %%
# мужчинам размер 100, женщинам - 10 (поменяли size_order)
g = sns.scatterplot(data=df, x='preTestScore', y='postTestScore', size=df.female, sizes=[10, 100], size_order=[1, 0])
# h, l = g.get_legend_handles_labels()
# plt.legend(h[0:3],l[0:3])
plt.title("preTestScore x postTestScore")
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
# Out:
# Text(0, 0.5, 'postTestScore')
